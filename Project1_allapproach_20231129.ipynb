# %%
import pandas as pd
import numpy as np
import math
from datetime import date
from scipy.optimize import minimize
from scipy.stats import norm
from scipy.interpolate import CubicSpline
from scipy.misc import derivative
import matplotlib.pyplot as plt

# %% [markdown]
# # Stock Prices on 27/10

# %%
S0_700  = 292.800
S0_0005 = 57.268
S0_941  = 62.850

# %% [markdown]
# # Risk Free Rate

# %%
#we assume risk-free rate and continuous dividend yield to be constant for simplicity
rf= 0.044667

# %% [markdown]
# # Estimating the dividend yield through Put Call Parity

# %%
Put_0005 = pd.read_csv("0005_Put.csv", index_col = 0, header = 0)
Call_0005 = pd.read_csv("0005_Call.csv", index_col=0, header = 0)
Put_0005.index = pd.to_datetime(Put_0005.index, format = "%d/%m/%Y")
Call_0005.index = pd.to_datetime(Call_0005.index, format = "%d/%m/%Y")

Put_941 = pd.read_csv("941_Put.csv", index_col = 0, header = 0)
Call_941 = pd.read_csv("941_Call.csv", index_col = 0, header = 0)
Put_941.index = pd.to_datetime(Put_941.index, format = "%d/%m/%Y")
Call_941.index = pd.to_datetime(Call_941.index, format = "%d/%m/%Y")



Put_700 = pd.read_csv("700_Put.csv", index_col = 0, header = 0)
Call_700 = pd.read_csv("700_Call.csv", index_col = 0, header = 0)
Put_700.index = pd.to_datetime(Put_700.index, format = "%d/%m/%Y")
Call_700.index = pd.to_datetime(Call_700.index, format = "%d/%m/%Y")

# %%
#maturity we used for options
Call_700.index.unique()
# Out:
# DatetimeIndex(['2023-10-30', '2023-11-29', '2023-12-28', '2024-01-30',
#                '2024-03-27', '2024-06-27', '2024-09-27'],
#               dtype='datetime64[ns]', name='Expiry Date', freq=None)

# %%
def dividend_estimation(S0, rf, Call_Price, Put_Price):
    dividend_list = []
    for dates in Put_Price.index.unique():
        #we only use ATM that strike to estimate the dividend yield 
        #since it has the most liquidity and gives more accurate results
        Call_price = list(map(lambda x,y: (x+y)/2,Call_Price.loc[Call_Price.index == dates, "Bid"].tolist(),Call_Price.loc[Call_Price.index == dates , "Ask"].tolist()))
        Put_price  = list(map(lambda x,y: (x+y)/2,Put_Price.loc[Put_Price.index == dates , "Bid"].tolist(),Put_Price.loc[Put_Price.index == dates , "Ask"].tolist()))
        C_min_P = map(lambda x,y: x-y, Call_price, Put_price)
        strike = Put_Price.loc[Put_Price.index == dates, "Strike"].tolist()
        strike = [K*np.exp(-rf*(3+ ((dates.year-2023)*12+dates.month-10)*21)/252) for K in strike]
        dividends = map(lambda x,y: np.log((x+y)/S0)*(-1/((2+((dates.year-2023)*12+dates.month-10)*21)/252)),C_min_P, strike)
        dividends = map(lambda x: np.maximum(0,x), list(dividends))
        dividends = np.mean(list(dividends))
        dividend_list.append(dividends)
    return np.mean(dividend_list)

# %%
q_0005 = dividend_estimation(S0_0005, rf, Call_0005, Put_0005)
q_700 = dividend_estimation(S0_700, rf, Call_700, Put_700)
q_941 = dividend_estimation(S0_941, rf, Call_941, Put_941)

# %%
q_0005, q_700, q_941
# Out:
# (0.04381506377660647, 0.029034348980198004, 0.0945491089515288)

# %% [markdown]
# # Get Implied Volatility at specific points

# %%
#idea: for each maturity, fit the implied volatility given in the notes,
#then, when we input a specific K and T, run cublic splines on that K across different maturities

# %%
#function stated in the notes
def implied_var_curve(x, atm_vol, delta, gamma, kappa):
    #change to log moneyness
    #put in the np.max to avoid negative variance during the optimization process
    return  atm_vol**2+delta*(np.tanh(kappa*x)/kappa)+(gamma/2)*(np.tanh(kappa*x)/kappa)**2

#function to find implied vol
def European_option_pricer(S,K,r,q,T,sig,isCall=True):
    d1 = (np.log(S/K)+(r-q+(sig**2)/2)*T)/(sig*(T**0.5))
    d2 = d1 - sig*(T**0.5)
    
    if isCall:
        return S*math.exp(-q*T)*norm.cdf(d1)-K*math.exp(-r*T)*norm.cdf(d2)
    else:
        return K*math.exp(-r*T)*norm.cdf(-d2)-S*math.exp(-q*T)*norm.cdf(-d1)

def implied_vol_bisection(V,S,K,r,q,T,option_pricer = European_option_pricer,isCall = True, tol = 0.00001):
    #V is the option price, either call or put price
    
    def f(sig): #function of sigma that returns the option price
        return option_pricer(S,K,r,q,T,sig,isCall)
    
    sig1 = 0.001 #Left sigma
    if f(sig1) >V:
         return ("Impossible to reach this option price solely changing the volatility")
    sig2 = 100 #right sigma
    while not(f(sig1)<V and f(sig2)>V):
        sig2+=0.2 #incrementing the bound until the true option price is within the sigma range
    sig_mean = (sig1+sig2)/2 #mid point
    
    while abs(f(sig_mean) - V) > tol: #iterating until the absolute difference is less than the tolerance level
        if f(sig_mean)-V>0: #it means it the sigma is on the RHS of the true sigma (since it's an increasing function)
            sig2 = sig_mean
            sig_mean = (sig1+sig2)/2 
        else:
            sig1 = sig_mean
            sig_mean = (sig1+sig2)/2
    return sig_mean

# %%
#function to find out the ATM vol
#we use the average of the closest strike price implied vol between Put and Call
#we take the closest strike and use the average of call and put implied vol
def atm_vol_cal(S0, Put_df, Call_df,T, r,q):
    closest_strike = min(Put_df.Strike.unique(), key=lambda x: abs(S0 - x))
    Call_implied_vol = implied_vol_bisection((Call_df.loc[Call_df["Strike"]==closest_strike, "Bid"].squeeze()+
                                              Call_df.loc[Call_df["Strike"]==closest_strike, "Ask"].squeeze())/2, S0, closest_strike, r, q, T, isCall=True)
    Put_implied_vol = implied_vol_bisection((Put_df.loc[Put_df["Strike"]==closest_strike, "Bid"].squeeze()+
                                            Put_df.loc[Put_df["Strike"]==closest_strike, "Ask"].squeeze())/2, S0, closest_strike, r, q, T, isCall=False)
    return np.mean([Call_implied_vol,Put_implied_vol])

# %%
### get iv for all strikes
def return_iv_df(S0, Put_df, Call_df,T,r,q,atm_vol):  
    otm_put_strikes = [float(K) for K in Put_df['Strike'] if K <= S0]
    otm_call_strikes = [float(K) for K in Call_df['Strike'] if K > S0]
    all_strike_levels = otm_put_strikes + otm_call_strikes
    closest_strike = min(Put_df.Strike.unique(), key=lambda x: abs(S0 - x))
    iv = pd.DataFrame(index = [T], columns = all_strike_levels)
    for j in range(len(iv.columns)):
        K = float(iv.columns[j])
        if K == closest_strike:
            iv.iloc[0,j] = atm_vol
        elif K<closest_strike:
            V = (Put_df.loc[Put_df["Strike"]==K, "Bid"].squeeze() +Put_df.loc[Put_df["Strike"]==K, "Ask"].squeeze())/2
            isCall = False
            iv.iloc[0,j] = implied_vol_bisection(V,S0,K,r,q,T,isCall=isCall)
        elif K > closest_strike:
            V = (Call_df.loc[Call_df["Strike"] == K, "Bid"].squeeze()+Call_df.loc[Call_df["Strike"] == K, "Ask"].squeeze())/2
            isCall = True
            iv.iloc[0,j] = implied_vol_bisection(V,S0,K,r,q,T,isCall=isCall)

    return iv

# %% [markdown]
# # Convert Implied vol to Local vol

# %%
#Convert option prices to local vol using dupire formula
def dupire(S,K,r,q,T,sig,isCall = True):
    dt = 1/252
    C = European_option_pricer(S,K,r,q,T,sig,isCall)
    dC_dT = (European_option_pricer(S,K,r,q,T+dt,sig,isCall) - European_option_pricer(S,K,r,q,T,sig,isCall))/dt
    
    dk = 0.05
    dC_dK = (European_option_pricer(S,K+dk,r,q,T,sig,isCall) - European_option_pricer(S,K-dk,r,q,T,sig,isCall))/(2*dk)
    d2C_dK2 = (European_option_pricer(S,K+dk,r,q,T,sig,isCall)
               -2*European_option_pricer(S,K,r,q,T,sig,isCall)
               +European_option_pricer(S,K-dk,r,q,T,sig,isCall))/(dk**2)
    return np.sqrt((dC_dT + (r-q)*K*dC_dK + q*C)/(0.5*K**2*d2C_dK2))

#return a dataframe containing local vol at specific points and time using Dupire's formula
def return_lcv_df(iv,S0,r,q):
    lcv = pd.DataFrame(index = iv.index, columns = iv.columns)

    for i in range(len(iv)):
        T = float(iv.index[i])
        for j in range(len(iv.columns)):
            K = float(iv.columns[j])
            isCall = False if K < S0 else True
            sig = iv.iloc[i,j]
            lcv.iloc[i,j] = dupire(S0,K,r,q,T,sig,isCall)
    return lcv

#Vol curve model
def implied_var_curve(x, atm_vol, skew, convex, wings):
        return atm_vol**2 + skew*(np.tanh(wings*x)/wings) + convex/2*(np.tanh(wings*x)/wings)**2

# %% [markdown]
# # Monte Carlo Simulation and Finding PR

# %%
#      700     5      941
# 700    1   0.433  0.295
#  5   0.433   1    0.376
# 941  0.295 0.376    1
correlation_matrix = np.array([np.array([1, 0.433,  0.295]),np.array([0.433, 1,0.376]),np.array([0.295,0.376,1])])

# %%
correlation_matrix
# Out:
# array([[1.   , 0.433, 0.295],
#        [0.433, 1.   , 0.376],
#        [0.295, 0.376, 1.   ]])

# %%
#parameter to estimate, r,q,local vol,corr
class MC:
    def __init__(self, corr_matrix, vol_func_1, vol_func_2, vol_func_3, S0_1, S0_2, S0_3,r,q1,q2,q3):
        """ 
        corr_matrix: correlation matrix for the 3 assets
        vol_func_1/2/3 is the function/matrix for the BS vol/ local vol for the 3 underlyings
        treat it as a function of t and strike temporarily
        S0_1 here is 700
        S0_2 here is 0005
        S0_3 here is 941
        """
        #save the input, which is the corr matrix, and the local vol function 
        self.corr_matrix = corr_matrix
        self.vol_func_1 = vol_func_1
        self.vol_func_2 = vol_func_2
        self.vol_func_3 = vol_func_3
        self.S0_1 = S0_1
        self.S0_2 = S0_2
        self.S0_3 = S0_3
        self.r = r
        self.q1 = q1
        self.q2 = q2
        self.q3 = q3
        
        self.time_step = 1*252 #252 trading days, 7 hours per day, 60 minutes per hour
        self.scenarios = 1000
        self.dt = 1/self.time_step
        np.random.seed(1)
        #time_step+1 because we set the first column to be our initial stock price
        self.bm_1 = pd.DataFrame(np.random.normal(size = (self.scenarios, self.time_step+1)))
        self.bm_2 = pd.DataFrame(np.random.normal(size = (self.scenarios, self.time_step+1)))
        self.bm_3 = pd.DataFrame(np.random.normal(size = (self.scenarios, self.time_step+1)))
        
        #generate the cholesky decomposition for the correlation matrix
        self.cholesky_matrix = np.linalg.cholesky(self.corr_matrix)
        
    def generate_zi(self, w1, w2, w3):
        return tuple(np.dot(self.cholesky_matrix,np.array([w1,w2,w3])))
                      
    def mc_underlying(self):
        """ 
        S0_1/2/3 is the initial price for the 3 underlying
        """
        self.underlying1 = pd.DataFrame().reindex_like(self.bm_1)
        self.underlying2 = pd.DataFrame().reindex_like(self.bm_2)
        self.underlying3 = pd.DataFrame().reindex_like(self.bm_3)
        self.underlying1.iloc[:,0] = self.S0_1
        self.underlying2.iloc[:,0] = self.S0_2
        self.underlying3.iloc[:,0] = self.S0_3
        sqrt_dt = np.sqrt(self.dt)
        for i in range(1,self.time_step+1):
            for j in range(self.scenarios):
                #generate the correlated brownian motion for the 3 underlying
                z1,z2,z3 = self.generate_zi(self.bm_1.iloc[j,i], self.bm_2.iloc[j,i], self.bm_3.iloc[j,i])
                vol_1 = self.vol_func_1(t = i*self.dt, K= self.underlying1.iloc[j,i-1])
                vol_2 = self.vol_func_2(t = i*self.dt, K= self.underlying2.iloc[j,i-1])
                vol_3 = self.vol_func_3(t = i*self.dt, K= self.underlying3.iloc[j,i-1])
                
                self.underlying1.iloc[j,i] = self.underlying1.iloc[j,i-1]*np.exp((self.r-self.q1-(vol_1**2)/2)*self.dt +vol_1*z1*sqrt_dt)
                self.underlying2.iloc[j,i] = self.underlying2.iloc[j,i-1]*np.exp((self.r-self.q2-(vol_2**2)/2)*self.dt +vol_2*z2*sqrt_dt)
                self.underlying3.iloc[j,i] = self.underlying3.iloc[j,i-1]*np.exp((self.r-self.q3-(vol_3**2)/2)*self.dt +vol_3*z3*sqrt_dt)
            if(i%10 ==0):
                print(i, "step finish")
        print("-"*100)

# %%
def payoff(PR, mc_obj):
    payoff = 0
    for i in range(mc_obj.scenarios):
        #just have to check the last trading day price
        #store all payoff in an array, and then mean and discount it back
        u_1 = mc_obj.underlying1.iloc[i,-1]
        u_2 = mc_obj.underlying2.iloc[i,-1]
        u_3 = mc_obj.underlying3.iloc[i,-1]
        laggard = np.min([u_1/mc_obj.S0_1, u_2/mc_obj.S0_2, u_3/mc_obj.S0_3])
        if laggard >= 1:
            payoff+= 1+PR*(laggard-1)
        else:
            payoff+= np.max([laggard,0.9])
    payoff = payoff/mc_obj.scenarios
    payoff = payoff*np.exp(-mc_obj.r*1)
    return payoff

# %%
def minimize_PR(mc_obj,target_payoff=0.98):
    
    def min_payoff(PR,mc_obj,target_payoff):
        final_payoff = payoff(PR, mc_obj)
        return np.abs(target_payoff - final_payoff)
    init_guess =1.2
    PR_min = minimize(min_payoff, init_guess, args = (mc_obj, target_payoff), method = 'SLSQP')
    return PR_min.x

# %% [markdown]
# # Implementation

# %% [markdown]
# # Approach 1: Fit BS vol surface

# %%
def fit_param(vol_df,S0,atm_vol):
    x = np.log(pd.to_numeric(vol_df.columns.to_list())/S0)
    y = [vol**2 for vol in vol_df.iloc[0].to_list()]

    def obj(x, y, skew, convex, wings):
        return np.sum((y - implied_var_curve(x, atm_vol, skew, convex, wings))**2)

    res = minimize(lambda coeffs: obj(x,y,*coeffs), x0=(-1,1,3), method='SLSQP')
    #res = minimize(lambda coeffs: obj(x,y,*coeffs), x0=(-1,1,3), method='COBYLA')
    return res.x

def fit_implied_vol_param_across_dates(S0, Put_df, Call_df, r, q):
    param = pd.DataFrame(index = Put_df.index.unique()[1:], columns = ['skew', 'convex', 'wings'])
    atm_vols_df = pd.DataFrame(index = Put_df.index.unique()[1:], columns = ['atm_vol'])
    for i in range(len(param.index)):
        date = param.index[i]
        T = (2+ ((date.year-2023)*12+date.month-10)*21)/252
        sub_put_df = Put_df[(Put_df.index == date) ]
        sub_call_df = Call_df[(Call_df.index == date)]
        atm_vol = atm_vol_cal(S0, sub_put_df, sub_call_df, T, r, q)
        iv = return_iv_df(S0, sub_put_df, sub_call_df, T, r, q, atm_vol)
        #lcv = return_lcv_df(iv,S0,r,q)
        param.iloc[i] = fit_param(iv,S0,atm_vol)
        atm_vols_df.iloc[i] = atm_vol
    return param, atm_vols_df

# %%
fitted_implied_vol_param_0005, atm_vols_0005 = fit_implied_vol_param_across_dates(S0_0005, Put_0005, Call_0005, rf,q_0005)
fitted_implied_vol_param_700, atm_vols_700 = fit_implied_vol_param_across_dates(S0_700, Put_700, Call_700, rf,q_700)
fitted_implied_vol_param_941, atm_vols_941 = fit_implied_vol_param_across_dates(S0_941, Put_941, Call_941, rf,q_941)

# %%
fitted_implied_vol_param_0005, fitted_implied_vol_param_700, fitted_implied_vol_param_941
# Out:
# (                 skew    convex     wings
#  Expiry Date
#  2023-11-29  -0.185521  3.278295  0.955828
#  2023-12-28  -0.146538   2.02057  1.676782
#  2024-01-30  -0.111001  1.806052  2.873357
#  2024-03-27  -0.128391  0.508931  0.926466
#  2024-06-27  -0.136755  0.682306   3.17286
#  2024-09-27  -0.108544  0.583097   3.20637,
#                   skew    convex     wings
#  Expiry Date
#  2023-11-29  -0.032483  3.050766  2.683678
#  2023-12-28  -0.028335  1.881766  2.872934
#  2024-01-30  -0.010653  1.185994  3.035433
#  2024-03-27   0.012973  0.951831  3.093296
#  2024-06-27   0.010228   0.57718  3.146484
#  2024-09-27   0.035221   0.17369  3.225968,
#                   skew    convex     wings
#  Expiry Date
#  2023-11-29   -0.01628  3.356409  0.001349
#  2023-12-28  -0.018509  1.337279  0.004973
#  2024-01-30  -0.001438  1.325208  3.013994
#  2024-03-27   0.021259  0.832812  3.166756
#  2024-06-27    0.03887  0.281101  3.321775
#  2024-09-27   0.038485  0.070944  3.375881)

# %%
def plot_Implied_vol_curve(S0, fitted_param, atm_vols_df, date):
    date = pd.to_datetime(date)
    atm_vol = float(atm_vols_df.loc[date])
    skew, convex, wings = fitted_param.loc[date]
    x = np.linspace(S0-10,S0+10,20)
    y = np.sqrt(implied_var_curve(np.log(x/S0),atm_vol,skew,convex,wings))
    plt.plot(x,y)
    plt.title(f"Implied vol curve for 0005.HK at {str(date)[:10]} across the strike")

#Local vol curve for 0005.HK at 2023-11-29 across the strike
plot_Implied_vol_curve(S0_0005, fitted_implied_vol_param_0005, atm_vols_0005, '2023-11-29')

# %%
def implied_vol_across_dates(t,K,S0,fitted_param,atm_vols_df): 
    dates = [(2+ ((date.year-2023)*12+date.month-10)*21)/252 for date in pd.to_datetime(fitted_param.index.to_list())]
    vols = []
    for i in range(len(fitted_param)):
        atmvol = float(atm_vols_df.iloc[i])
        skew, convex, wings = fitted_param.iloc[i]
        vol = np.sqrt(implied_var_curve(np.log(K/S0), atmvol, skew, convex, wings))
        vols.append(vol)
    cubicspline = CubicSpline(dates, vols, extrapolate=True)
    return cubicspline(t)

def implied_vol_1(t,K): #700
    return implied_vol_across_dates(t, K, S0_700, fitted_implied_vol_param_700, atm_vols_700)
def implied_vol_2(t,K): #0005
    return implied_vol_across_dates(t, K, S0_0005, fitted_implied_vol_param_0005, atm_vols_0005)
def implied_vol_3(t,K): #941
    return implied_vol_across_dates(t, K, S0_941, fitted_implied_vol_param_941, atm_vols_941)

# %%
def plot_3d_vol_surface(S0, bound, vol_func, name):
    from mpl_toolkits.mplot3d import axes3d
    from matplotlib import pyplot 

    num = 252
    x = np.linspace(S0-bound,S0+bound,num)
    y = np.linspace(0.01,1,num) 
    z = vol_func(y,x)

    # displaying the visualization
    x = np.array([list(x)]*num)
    y = np.array([list(y)]*num).T

    ax = plt.figure(figsize = (100,10)).add_subplot(projection='3d')
    ax.plot_surface(x, y, z, edgecolor='royalblue', lw=0.5, rstride=8, cstride=8,
                    alpha=0.3)
    ax.set_title(f'{name}')
    ax.contour(x, y, z, zdir='x', offset=S0-bound, cmap='coolwarm')
    ax.contour(x, y, z, zdir='y', offset=1, cmap='coolwarm')
    ax.set_xlabel('Strike')
    ax.set_ylabel('Time (in years)')
    ax.set_zlabel('Vol');
    plt.show()
    
plot_3d_vol_surface(S0_700, 50, implied_vol_1, '700.HK Implied vol surface')
plot_3d_vol_surface(S0_0005, 20, implied_vol_2, '0005.HK Implied vol surface')
plot_3d_vol_surface(S0_941, 20, implied_vol_3, '941.HK Implied vol surface')

# %%
mc_obj_bs = MC(correlation_matrix, implied_vol_1, implied_vol_2, implied_vol_3, S0_700, S0_0005, S0_941,rf,q_700,q_0005,q_941)
mc_obj_bs.mc_underlying()
minimize_PR(mc_obj_bs)
# Out:
# 10 step finish
# 20 step finish
# 30 step finish
# 40 step finish
# 50 step finish
# ..     ...        ...        ...        ...        ...        ...        ...
# 995  62.85  62.940480  62.582737  62.793945  63.064492  63.121393  62.924964
# 996  62.85  62.611885  63.543134  64.387340  64.345557  65.091093  64.542674
# 997  62.85  61.535473  61.842973  61.599157  61.544692  61.190330  61.981223
# 998  62.85  61.874018  62.391665  62.086300  61.685365  61.834856  62.382796
# 999  62.85  61.769997  61.379619  62.620376  62.863231  61.864419  61.182344
#
#            7          8          9    ...        243        244        245  \
# 0    63.846662  64.524473  64.500746  ...  83.192832  83.872015  83.424558
# 1    66.071520  64.682063  65.745142  ...  65.104607  64.242672  62.706694
# 2    63.394989  63.641058  63.160461  ...  57.642336  58.841842  57.463256
# 3    66.319798  65.537703  66.020098  ...  65.647876  65.273444  65.688941
# 4    64.082921  64.361359  64.629657  ...  77.670967  76.227986  78.256085
# ..         ...        ...        ...  ...        ...        ...        ...
# 995  61.914482  61.502486  61.482384  ...  57.283152  57.677859  58.343663
# 996  65.257997  65.716067  66.120757  ...  55.176904  54.107739  54.022008
# 997  61.251321  60.725904  60.899280  ...  57.062715  57.518730  56.905599
# 998  63.478696  63.395233  62.146657  ...  68.639810  67.103667  67.884018
# 999  61.011825  60.679167  60.694469  ...  70.262859  70.950199  71.235479
#
#            246        247        248        249        250        251  \
# 0    83.357094  84.288682  85.352243  84.877148  85.789943  85.882249
# 1    63.488166  64.151126  64.385859  64.300849  65.088674  66.576119
# 2    56.990814  58.128905  58.311688  57.568598  57.159043  56.727456
# 3    66.236527  65.375705  67.110268  65.365886  65.932443  66.218311
# 4    79.051742  79.632630  79.023858  79.824468  79.514272  79.127093
# ..         ...        ...        ...        ...        ...        ...
# 995  57.696001  58.310991  58.146490  57.914652  57.806397  57.149902
# 996  53.926620  54.211998  54.363523  55.114697  54.798858  54.638878
# 997  56.707863  56.950629  55.684414  55.198213  55.634530  55.164662
# 998  68.300125  67.292672  67.368850  66.478893  66.122220  64.552414
# 999  70.143009  70.699865  70.996338  71.470340  71.641968  72.580837
#
#            252
# 0    87.681800
# 1    67.443118
# 2    56.918760
# 3    66.037390
# 4    79.736211
# ..         ...
# 995  56.939406
# 996  53.622268
# 997  55.052710
# 998  63.372681
# 999  73.300141
#
# [1000 rows x 253 columns]
# array([5.11243275])

# %% [markdown]
# # Approach 2.1: Calculate local vol at specific points first using Dupire's formula, then fit curve and surface

# %%
#Convert option prices to local vol using dupire formula
def dupire(S,K,r,q,T,sig,isCall = True):
    dt = 1/252
    C = European_option_pricer(S,K,r,q,T,sig,isCall)
    dC_dT = (European_option_pricer(S,K,r,q,T+dt,sig,isCall) - European_option_pricer(S,K,r,q,T,sig,isCall))/dt
    
    dk = 0.05
    dC_dK = (European_option_pricer(S,K+dk,r,q,T,sig,isCall) - European_option_pricer(S,K-dk,r,q,T,sig,isCall))/(2*dk)
    d2C_dK2 = (European_option_pricer(S,K+dk,r,q,T,sig,isCall)
               -2*European_option_pricer(S,K,r,q,T,sig,isCall)
               +European_option_pricer(S,K-dk,r,q,T,sig,isCall))/(dk**2)
    return np.sqrt((dC_dT + (r-q)*K*dC_dK + q*C)/(0.5*K**2*d2C_dK2))

#return a dataframe containing local vol at specific points and time using Dupire's formula
def return_lcv_df(iv,S0,r,q):
    lcv = pd.DataFrame(index = iv.index, columns = iv.columns)

    for i in range(len(iv)):
        T = float(iv.index[i])
        for j in range(len(iv.columns)):
            K = float(iv.columns[j])
            isCall = False if K < S0 else True
            sig = iv.iloc[i,j]
            lcv.iloc[i,j] = dupire(S0,K,r,q,T,sig,isCall)
    return lcv


#Fit the paramater of the vol curve model across different maturity
def fit_lcv_param_across_dates_1(S0, Put_df, Call_df, r, q):
    param = pd.DataFrame(index = Put_df.index.unique()[1:], columns = ['skew', 'convex', 'wings'])
    atm_vols_df = pd.DataFrame(index = Put_df.index.unique()[1:], columns = ['atm_vol'])
    for i in range(len(param.index)):
        date = param.index[i]
        T = (2+ ((date.year-2023)*12+date.month-10)*21)/252
        sub_put_df = Put_df[(Put_df.index == date) ]
        sub_call_df = Call_df[(Call_df.index == date)]
        atm_vol = atm_vol_cal(S0, sub_put_df, sub_call_df, T, r, q)
        iv = return_iv_df(S0, sub_put_df, sub_call_df, T, r, q, atm_vol)
        lcv = return_lcv_df(iv,S0,r,q)
        param.iloc[i] = fit_param(lcv,S0,atm_vol)
        atm_vols_df.iloc[i] = atm_vol
    return param, atm_vols_df

# %%
fitted_param_0005, atm_vols_0005 = fit_lcv_param_across_dates_1(S0_0005, Put_0005, Call_0005, rf,q_0005)
fitted_param_700, atm_vols_700 = fit_lcv_param_across_dates_1(S0_700, Put_700, Call_700, rf,q_700)
fitted_param_941, atm_vols_941 = fit_lcv_param_across_dates_1(S0_941, Put_941, Call_941, rf,q_941)

# %%
fitted_param_0005, fitted_param_700, fitted_param_941
# Out:
# (                 skew    convex     wings
#  Expiry Date
#  2023-11-29   -0.18237  3.425964  0.834596
#  2023-12-28  -0.144585  2.046407  1.608418
#  2024-01-30  -0.109923  1.834918  2.864697
#  2024-03-27   -0.12293   0.49222  0.173417
#  2024-06-27  -0.136619  0.684623  3.171709
#  2024-09-27  -0.108325  0.583638  3.206154,
#                   skew    convex     wings
#  Expiry Date
#  2023-11-29  -0.030568   3.24221  2.644264
#  2023-12-28  -0.027538  1.927926  2.860171
#  2024-01-30  -0.010197  1.199825  3.032307
#  2024-03-27   0.012908  0.951825  3.093271
#  2024-06-27   0.010178  0.573303   3.14683
#  2024-09-27   0.035277  0.169373  3.226559,
#                   skew    convex     wings
#  Expiry Date
#  2023-11-29   -0.01699  3.547272  0.000283
#  2023-12-28  -0.019197  1.387968  0.039047
#  2024-01-30  -0.001909  1.361328  3.002976
#  2024-03-27   0.020555  0.845104  3.162704
#  2024-06-27   0.038611  0.285771  3.320351
#  2024-09-27   0.038301  0.072926  3.375245)

# %%
def plot_local_vol_curve(S0, fitted_param, atm_vols_df, date):
    date = pd.to_datetime(date)
    atm_vol = float(atm_vols_df.loc[date])
    skew, convex, wings = fitted_param.loc[date]
    x = np.linspace(S0-10,S0+10,20)
    y = np.sqrt(implied_var_curve(np.log(x/S0),atm_vol,skew,convex,wings))
    plt.plot(x,y)
    plt.title(f"Local vol curve for 0005.HK at {str(date)[:10]} across the strike")

#Local vol curve for 0005.HK at 2023-11-29 across the strike
plot_local_vol_curve(S0_0005, fitted_param_0005, atm_vols_0005, '2023-11-29')

# %%
#Return local vol given any time and strike
def local_vol(t,K,S0,fitted_param,atm_vols_df): 
    dates = [(2+ ((date.year-2023)*12+date.month-10)*21)/252 for date in pd.to_datetime(fitted_param.index.to_list())]
    vols = []
    for i in range(len(fitted_param)):
        atmvol = float(atm_vols_df.iloc[i])
        skew, convex, wings = fitted_param.iloc[i]
        vol = np.sqrt(implied_var_curve(np.log(K/S0), atmvol, skew, convex, wings))
        vols.append(vol)
    cubicspline = CubicSpline(dates, vols)
    return cubicspline(t)

def local_vol_1(t,K): #700
    return local_vol(t, K, S0_700, fitted_param_700, atm_vols_700)
def local_vol_2(t,K): #0005
    return local_vol(t, K, S0_0005, fitted_param_0005, atm_vols_0005)
def local_vol_3(t,K): #941
    return local_vol(t, K, S0_941, fitted_param_941, atm_vols_941)

# %%
plot_3d_vol_surface(S0_700, 50, local_vol_1, '700.HK Local vol surface')
plot_3d_vol_surface(S0_0005, 20, local_vol_2, '0005.HK Local vol surface')
plot_3d_vol_surface(S0_941, 20, local_vol_3, '941.HK Local vol surface')

# %%
mc_obj_lcv_1 = MC(correlation_matrix, local_vol_1, local_vol_2, local_vol_3, S0_700, S0_0005, S0_941,rf,q_700,q_0005,q_941)
mc_obj_lcv_1.mc_underlying()
minimize_PR(mc_obj_lcv_1)
# Out:
# 10 step finish
# 20 step finish
# 30 step finish
# 40 step finish
# 50 step finish
# 60 step finish
# 70 step finish
# 80 step finish
# 90 step finish
# 100 step finish
# 110 step finish
# 120 step finish
# 130 step finish
# 140 step finish
# 150 step finish
# 160 step finish
# 170 step finish
# 180 step finish
# 190 step finish
# 200 step finish
# 210 step finish
# 220 step finish
# 230 step finish
# 240 step finish
# 250 step finish
# ----------------------------------------------------------------------------------------------------
#        0           1           2           3           4           5    \
# 0    292.8  288.935817  285.650322  279.146866  284.360631  270.826078
# 1    292.8  295.059453  288.513937  301.296560  305.015564  307.766147
# 2    292.8  293.314379  289.534627  292.919200  303.493194  304.712696
# 3    292.8  302.573979  295.113473  288.330000  298.808503  302.604174
# 4    292.8  299.935392  310.137060  308.465744  312.170482  302.027664
# ..     ...         ...         ...         ...         ...         ...
# 995  292.8  291.657996  302.069175  307.881725  298.709407  309.855214
# 996  292.8  295.897461  301.008130  303.864971  303.294430  308.227903
# 997  292.8  297.410296  306.448478  311.201427  302.748077  294.971436
# 998  292.8  299.343125  300.463481  299.835665  301.749879  296.099435
# 999  292.8  293.453368  295.343966  293.113307  298.013426  301.405408
#
#             6           7           8           9    ...         243  \
# 0    281.458685  276.939612  278.781477  277.279095  ...  393.802811
# 1    303.757895  304.386496  294.810993  299.598827  ...  358.535443
# 999  61.013006  60.679523  60.694900  ...  70.261136  70.947948  71.232962
#
#            246        247        248        249        250        251  \
# 0    83.359280  84.289412  85.351129  84.876910  85.787815  85.879897
# 1    63.482676  64.145507  64.380173  64.295189  65.082756  66.569487
# 2    56.986109  58.124465  58.307287  57.564048  57.154404  56.722721
# 3    66.222149  65.361942  67.095419  65.352640  65.918824  66.204463
# 4    79.099750  79.680227  79.071958  79.871772  79.561920  79.175228
# ..         ...        ...        ...        ...        ...        ...
# 995  57.713944  58.329404  58.164781  57.932771  57.824436  57.167439
# 996  53.918717  54.204168  54.355730  55.107063  54.791169  54.631162
# 997  56.713951  56.956841  55.690010  55.203571  55.640104  55.170013
# 998  68.320437  67.313276  67.389436  66.499701  66.143074  64.573431
# 999  70.141591  70.697899  70.994029  71.467420  71.638790  72.576159
#
#            252
# 0    87.675066
# 1    67.435783
# 2    56.914071
# 3    66.023694
# 4    79.783446
# ..         ...
# 995  56.956784
# 996  53.614391
# 997  55.058011
# 998  63.393488
# 999  73.294107
#
# [1000 rows x 253 columns]
# array([5.11089428])

# %% [markdown]
# # Approach 2.2: Fit iv surface first, then convert each option price derived from iv to lcv using Dupire's formula

# %%
def implied_vol_across_dates(t,K,S0,fitted_param,atm_vols_df): 
    dates = [(2+ ((date.year-2023)*12+date.month-10)*21)/252 for date in pd.to_datetime(fitted_param.index.to_list())]
    vols = []
    for i in range(len(fitted_param)):
        atmvol = float(atm_vols_df.iloc[i])
        skew, convex, wings = fitted_param.iloc[i]
        vol = np.sqrt(implied_var_curve(np.log(K/S0), atmvol, skew, convex, wings))
        vols.append(vol)
    cubicspline = CubicSpline(dates, vols, extrapolate=True)
    return cubicspline(t)

# %%
local_vol_through_iv_0005 = lambda t,K: dupire(S0_0005, K, rf, q_0005, t, implied_vol_across_dates(t, K, S0_0005, fitted_implied_vol_param_0005,atm_vols_0005), K>S0_0005)
local_vol_through_iv_700 = lambda t,K: dupire(S0_700, K, rf, q_700, t, implied_vol_across_dates(t, K, S0_700, fitted_implied_vol_param_700,atm_vols_700), K>S0_700)
local_vol_through_iv_941 = lambda t,K: dupire(S0_941, K, rf, q_941, t, implied_vol_across_dates(t, K, S0_941, fitted_implied_vol_param_941,atm_vols_941), K>S0_941)

# %%
mc_obj_lcv_2 = MC(correlation_matrix, local_vol_through_iv_700, local_vol_through_iv_0005, local_vol_through_iv_941, S0_700, S0_0005, S0_941,rf,q_700,q_0005,q_941)
mc_obj_lcv_2.mc_underlying()
minimize_PR(mc_obj_lcv_2)
# Out:
# 10 step finish
# 20 step finish
# 30 step finish
# 40 step finish
# 50 step finish
# 60 step finish
# 70 step finish
# 80 step finish
# 90 step finish
# 100 step finish
# 110 step finish
# 120 step finish
# 130 step finish
# 140 step finish
# 150 step finish
# 160 step finish
# 170 step finish
# 180 step finish
# 190 step finish
# 200 step finish
# 210 step finish
# 220 step finish
# 230 step finish
# 240 step finish
# 250 step finish
# ----------------------------------------------------------------------------------------------------
#        0           1           2           3           4           5    \
# 0    292.8  289.288145  286.150702  279.801055  285.009985  271.684957
#
#            7          8          9    ...        243        244        245  \
# 0    63.782746  64.449772  64.426257  ...  83.106081  83.784223  83.337442
# 1    66.143331  64.735756  65.794829  ...  65.138930  64.276850  62.740577
# 2    63.355646  63.597725  63.123731  ...  57.606771  58.804675  57.428055
# 3    66.226326  65.443862  65.922326  ...  65.565220  65.191666  65.606176
# 4    63.954213  64.227485  64.491224  ...  77.393688  75.958284  77.975576
# ..         ...        ...        ...  ...        ...        ...        ...
# 995  61.927407  61.520218  61.500225  ...  57.306930  57.701687  58.367559
# 996  65.188674  65.643310  66.045915  ...  55.122009  54.054490  53.968873
# 997  61.380669  60.860564  61.032590  ...  57.226894  57.684529  57.069226
# 998  63.543565  63.460980  62.225580  ...  68.753622  67.214822  67.996521
# 999  61.134138  60.804254  60.819392  ...  70.337667  71.025639  71.311183
#
#            246        247        248        249        250        251  \
# 0    83.270078  84.200183  85.262056  84.787704  85.699012  85.791162
# 1    63.522097  64.185190  64.419965  64.334937  65.122901  66.610574
# 2    56.956221  58.092882  58.275410  57.533339  57.124313  56.693264
# 3    66.152464  65.293650  67.024143  65.283805  65.849043  66.134244
# 4    78.766961  79.344699  78.739227  79.535426  79.226938  78.841912
# ..         ...        ...        ...        ...        ...        ...
# 995  57.719850  58.334905  58.170389  57.938530  57.830261  57.173691
# 996  53.873612  54.158609  54.309924  55.060050  54.744685  54.584933
# 997  56.870796  57.114425  55.843737  55.355850  55.793673  55.322183
# 998  68.413341  67.404171  67.480479  66.589020  66.231743  64.659287
# 999  70.217693  70.775053  71.071796  71.546233  71.718020  72.657763
#
#            252
# 0    87.587702
# 1    67.477678
# 2    56.884332
# 3    65.953730
# 4    79.447575
# ..         ...
# 995  56.963160
# 996  53.569758
# 997  55.209852
# 998  63.477510
# 999  73.377760
#
# [1000 rows x 253 columns]
# array([5.12605467])

# %%
def plot_3d_vol_surface_2(S0, bound, vol_func, name):
    from mpl_toolkits.mplot3d import axes3d
    from matplotlib import pyplot 

    num = 100
    x = np.linspace(S0-bound,S0+bound,num)
    y = np.linspace(0.05,1,num) 
    z = []
    for i in x:
        tmp = []
        for j in y:
            tmp.append(vol_func(j,i))
        z.append(tmp)
    z = np.array(z).T
    # displaying the visualization

    x = np.array([list(x)]*num)
    y = np.array([list(y)]*num).T

    ax = plt.figure(figsize = (100,10)).add_subplot(projection='3d')
    ax.plot_surface(x, y, z, edgecolor='royalblue', lw=0.5, rstride=8, cstride=8,
                    alpha=0.3)
    ax.set_title(f'{name}')
    ax.contour(x, y, z, zdir='x', offset=S0-bound, cmap='coolwarm')
    ax.contour(x, y, z, zdir='y', offset=1, cmap='coolwarm')
    ax.set_xlabel('Strike')
    ax.set_ylabel('Time (in years)')
    ax.set_zlabel('Vol');
    plt.show()
    
plot_3d_vol_surface_2(S0_700, 50, local_vol_through_iv_700, '700.HK Local vol surface')
plot_3d_vol_surface_2(S0_0005, 20, local_vol_through_iv_0005, '0005.HK Local vol surface')
plot_3d_vol_surface_2(S0_941, 20, local_vol_through_iv_941, '941.HK Local vol surface')
